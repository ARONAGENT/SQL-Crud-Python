# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 1.8 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
con=pymysql.connect(host="rohan-mysql-db-rohandbconnections.c.aivencloud.com",user="avnadmin",password="AVNS_jLvqn4KtNKeQMfTv6yn",port=19414,database="rohandb")
print('connect with database successfully')
# Out:
# connect with database successfully

# %%
curs=con.cursor()

# %%
no=int(input('Enter account no :'))
nm=input('Enter account name :')
ty=input('Enter Account Type:')
bal=float(input("Enter Balance :"))
# Out:
# Enter account no :1021
# Enter account name :Rohan Uke
# Enter Account Type:PPF
# Enter Balance :45000

# %%
curs.execute("insert into accounts values (%d,'%s','%s','%.2f')"%(no,nm,ty,bal))
# Out:
# 1

# %%
con.commit()
print('data inserted successfully')
# Out:
# data inserted successfully

# %% [markdown]
# **table with auto increment insertion**
# CREATE TABLE actors (
#     actor_id INT AUTO_INCREMENT PRIMARY KEY,
#     first_name VARCHAR(50),
#     last_name VARCHAR(50),
#     birthdate varchar(10),
#     nationality VARCHAR(50)
# );

# %%
fnm=input('Enter first name :')
lnm=input('Enter last name :')
bir=input('Enter Birthdate (YY-MM-DD):')
nat=input('Enter country :')
# Out:
# Enter first name :Amir
# Enter last name :Khan
# Enter Birthdate (YY-MM-DD):1965-03-14
# Enter country :India

# %%
curs.execute("insert into actors (first_name,last_name,birthdate,nationality) values ('%s','%s','%s','%s')"%(fnm,lnm,bir,nat))
# Out:
# 1

# %%
con.commit()
print('data inserted successfully')
# Out:
# data inserted successfully
