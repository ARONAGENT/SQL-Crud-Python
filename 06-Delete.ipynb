# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 3.1 MB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
con=pymysql.connect(host="rohan-mysql-db-rohandbconnections.c.aivencloud.com",user="avnadmin",password="",port=19414,database="rohandb")
print('connect with database successfully')
# Out:
# connect with database successfully

# %%
curs=con.cursor()

# %% [markdown]
# **Perform Delete Operation on Cars**

# %%
id=int(input('Enter car id :'))
# Out:
# Enter car id :5

# %%
curs.execute("delete from cars where carid=%d" %id)
# Out:
# 1

# %%
con.commit()
print('delete carid=%d successfully'%id)
# Out:
# delete carid=5 successfully

# %%
con.close()
