# %%
pip install pymysql
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 564.4 kB/s eta 0:00:00
# ...

# %%
import pymysql

# %%
con=pymysql.connect(host="rohan-mysql-db-rohandbconnections.c.aivencloud.com",user="avnadmin",password="AVNS_jLvqn4KtNKeQMfTv6yn",port=19414,database="rohandb")
print('connect with database successfully')
# Out:
# connect with database successfully

# %%
curs=con.cursor()

# %% [markdown]
# **Searching Operation from Films table**
#
# CREATE TABLE films (
#     film_id INT PRIMARY KEY,
#     title VARCHAR(100),
#     director VARCHAR(100),
#     release_year INT,
#     genre VARCHAR(50),
#     duration INT, -- duration in minutes
#     rating FLOAT -- rating out of 10
# );

# %%
nm=input('Enter film-title name :')
# Out:
# Enter film-title name :PK

# %%
curs.execute("select * from films where title='%s'"%nm)
# Out:
# 1

# %%
curs.fetchall()
# Out:
# ((207, 'PK', 'Rajkumar Hirani', 2014, 'Comedy', 153, 8.1),)

# %% [markdown]
# **Search Operation from accounts Table**
#
# create table accounts(
#   accno int primary key,
#   accnm varchar(50),
#   acctype varchar(50),
#   balance float
# );

# %%
acctype=input('enter acctype :')
# Out:
# enter acctype :Savings

# %%
curs.execute("select * from accounts where acctype='%s'"%acctype)
# Out:
# 10

# %%
for data in curs.fetchall():
  print(data)
# Out:
# (1001, 'Amit Kumar', 'Savings', 50000.5)
# (1003, 'Rahul Singh', 'Savings', 25000.0)
# (1005, 'Vikas Patel', 'Savings', 32000.0)
# (1007, 'Suman Rao', 'Savings', 40000.0)
# (1009, 'Rakesh Gupta', 'Savings', 60000.8)
# (1011, 'Vijay Reddy', 'Savings', 54000.9)
# (1013, 'Rohit Verma', 'Savings', 70000.0)
# (1015, 'Nitin Saxena', 'Savings', 55000.5)
# (1017, 'Suresh Yadav', 'Savings', 46000.1)
# (1019, 'Rajiv Bhatia', 'Savings', 52000.7)

# %%
con.close()
