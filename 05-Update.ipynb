# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 2.6 MB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %%
import pymysql

# %%
con=pymysql.connect(host="rohan-mysql-db-rohandbconnections.c.aivencloud.com",user="avnadmin",password="AVNS_jLvqn4KtNKeQMfTv6yn",port=19414,database="rohandb")
print('connect with database successfully')
# Out:
# connect with database successfully

# %%
curs=con.cursor()

# %% [markdown]
# **Performing Update Operation on accounts table**

# %%
acc=int(input('Enter a account no :'))
balance=float(input('Enter balance:'))
# Out:
# Enter a account no :1007
# Enter balance:45000

# %%
curs.execute("update accounts set balance=%f where accno=%d" %(balance,acc))
# Out:
# 1

# %%
con.commit()

# %%
print("Account update successfully")
# Out:
# Account update successfully

# %%
con.close()
