# %%
pip install pymysql
# Out:
# Collecting pymysql
#   Downloading PyMySQL-1.1.1-py3-none-any.whl.metadata (4.4 kB)
# Downloading PyMySQL-1.1.1-py3-none-any.whl (44 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 45.0/45.0 kB 788.9 kB/s eta 0:00:00
# Installing collected packages: pymysql
# Successfully installed pymysql-1.1.1

# %%
import pymysql

# %%
con=pymysql.connect(host="rohan-mysql-db-rohandbconnections.c.aivencloud.com",user="avnadmin",password="AVNS_jLvqn4KtNKeQMfTv6yn",port=19414,database="rohandb")
print('connect with database successfully')
# Out:
# connect with database successfully

# %%
curs=con.cursor()

# %%
curs.execute("select * from cars")
# Out:
# 25

# %%
for data in curs.fetchall():
  print(data)
# Out:
# (1, 'Model S', 'Tesla', 80000.0)
# (2, 'Mustang', 'Ford', 55999.9)
# (3, 'Civic', 'Honda', 24999.9)
# (4, 'Corolla', 'Toyota', 24000.0)
# (5, 'A4', 'Audi', 45999.5)
# (6, '3 Series', 'BMW', 41000.0)
# (7, 'Model 3', 'Tesla', 36000.0)
# (8, 'Camry', 'Toyota', 27999.8)
# (9, 'Accord', 'Honda', 31999.4)
# (10, 'Challenger', 'Dodge', 40000.0)
# (11, 'S-Class', 'Mercedes-Benz', 100000.0)
# (12, 'Taycan', 'Porsche', 105000.0)
# (13, 'Altima', 'Nissan', 24999.5)
# (14, 'Golf', 'Volkswagen', 23000.0)
# (15, 'CX-5', 'Mazda', 28999.8)
# (16, 'Roadster', 'Tesla', 200000.0)
# (17, 'F-150', 'Ford', 29000.0)
# (18, 'CR-V', 'Honda', 28000.0)
# (19, 'Highlander', 'Toyota', 35999.5)
# (20, 'Q7', 'Audi', 55000.0)
# (21, 'X5', 'BMW', 61000.0)
# (22, 'Model X', 'Tesla', 90000.0)
# (23, 'RAV4', 'Toyota', 30999.5)
# (24, 'Pilot', 'Honda', 35000.0)
# (25, 'Durango', 'Dodge', 42000.0)

# %%
curs.fetchone()
# Out:
# (1, 'Model S', 'Tesla', 80000.0)

# %%
curs.fetchmany(5)
# Out:
# ((2, 'Mustang', 'Ford', 55999.9),
#  (3, 'Civic', 'Honda', 24999.9),
#  (4, 'Corolla', 'Toyota', 24000.0),
#  (5, 'A4', 'Audi', 45999.5),
#  (6, '3 Series', 'BMW', 41000.0))

# %%
curs.execute("select * from cars where companyname='BMW'")
# Out:
# 2

# %%
curs.fetchall()
# Out:
# ((6, '3 Series', 'BMW', 41000.0), (21, 'X5', 'BMW', 61000.0))

# %%
con.close()
